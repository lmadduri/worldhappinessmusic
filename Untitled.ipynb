# %%
import pandas as pd
df = pd.read_csv("/Users/lalitha/Documents/fycharts/src/2017/top_200_weekly_uy_2017.csv")

# %%
df
# Out:
#       Position                                         Track Name  \
# 0          1.0                         Reggaetón Lento (Bailemos)
# 1          2.0                            Cuando Se Pone a Bailar
# 2          3.0                            Chantaje (feat. Maluma)
# 3          4.0                 Despacito (Featuring Daddy Yankee)
# 4          5.0                                             Safari
# ...        ...                                                ...
# 9995     196.0  Let Me Go (with Alesso, Florida Georgia Line &...
# 9996     197.0                               Que Se Apague La Luz
# 9997     198.0                             Joga O Bum Bum Tam Tam
# 9998     199.0                                        Baila lento
# 9999     200.0                                        No Te Hagas
#
#                 Artist  Streams                    date region  \
# 0                 CNCO  92411.0  2017-01-13--2017-01-20     uy
# ...

# %%
df_copy = df.groupby(['Track Name', 'spotify_id'])['Streams'].sum()

# %%
df_copy.sort_values(ascending=False)[0:10]
# Out:
# Track Name                          spotify_id
# Despacito (Featuring Daddy Yankee)  4aWmUDTfIPGksMNLV2rQP2    3428318.0
# Me Rehúso                           6De0lHrwBfPfrhorm9q1Xl    2808433.0
# Shape of You                        7qiZfU4dY1lWllzX7mPBI3    2610908.0
# Felices los 4                       0qYTZCo5Bwh1nsUFGZP3zn    2312236.0
# El Amante                           3umS4y3uQDkqekNjVpiRUs    2157353.0
# Ahora Dice                          22eADXu8DfOAUEDw4vU8qy    1995304.0
# La Rompe Corazones                  4okba5wu9mMLXx79DXLKi3    1959360.0
# Otra vez (feat. J Balvin)           3QwBODjSEzelZyVjxPOHdq    1945883.0
# Reggaetón Lento (Bailemos)          3AEZUABDXNtecAOSC1qTfo    1878009.0
# Escápate Conmigo                    2cnKEkpVUSV4wnjQiTWfH6    1849212.0
# Name: Streams, dtype: float64
